# %%
import pandas as pd

from sklearn import datasets

from evidently.test_suite import TestSuite
from evidently.test_preset import DataStabilityTestPreset

from evidently.report import Report
from evidently.metric_preset import DataDriftPreset

# %%
iris_data = datasets.load_iris(as_frame=True)

# %%
iris_frame = iris_data.frame

# %%
iris_frame.shape
# Out:
# (150, 5)

# %%
data_stability= TestSuite(tests=[
    DataStabilityTestPreset(),
])

data_stability.run(current_data=iris_frame.iloc[:60], reference_data=iris_frame.iloc[60:], column_mapping=None)
# Out:
# /home/sumit/.local/lib/python3.10/site-packages/evidently/calculations/data_integration.py:41: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /home/sumit/.local/lib/python3.10/site-packages/evidently/calculations/data_integration.py:41: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /home/sumit/.local/lib/python3.10/site-packages/evidently/calculations/data_integration.py:41: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /home/sumit/.local/lib/python3.10/site-packages/evidently/calculations/data_integration.py:41: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /home/sumit/.local/lib/python3.10/site-packages/evidently/calculations/data_integration.py:41: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# /home/sumit/.local/lib/python3.10/site-packages/evidently/calculations/data_integration.py:41: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead

# %%
data_drift_report = Report(metrics=[
    DataDriftPreset(),
])

data_drift_report.run(current_data=iris_frame.iloc[:60], reference_data=iris_frame.iloc[60:], column_mapping=None)
data_drift_report
# Out:
# /home/sumit/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:8064: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /home/sumit/.local/lib/python3.10/site-packages/scipy/stats/_stats_py.py:8064: RuntimeWarning:
#
# divide by zero encountered in divide
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_e5353efe5e41408db532e6694669ab9e = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "e299dfb4-05b2-401d-868a-3c5a0a8deecc", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "Dataset Drift", "label": "Dataset Drift is detected. Dataset drift detection threshold is 0.5"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "14cb5e70-b55b-49ee-98a2-88bf0fad5bc7", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "5", "label": "Columns"}, {"value": "5", "label": "Drifted Columns"}, {"value": "1.0", "label": "Share of Drifted Columns"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "counter", "title": "", "size": 2, "id": "aa650a35-5247-4938-861d-b0a71a197181", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Data Drift Summary"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "big_table", "title": "Drift is detected for 100.0% of columns (5 out of 5).", "size": 2, "id": "86e44d3e-7e08-481a-9c58-cf6989fa0c77", "details": "", "alertsPosition": "row", "alertStats": null, "params": {"rowsPerPage": 5, "columns": [{"title": "Column", "field": "column_name"}, {"title": "Type", "field": "column_type"}, {"title": "Reference Distribution", "field": "reference_distribution", "type": "histogram", "options": {"xField": "x", "yField": "y", "color": "#ed0400"}}, {"title": "Current Distribution", "field": "current_distribution", "type": "histogram", "options": {"xField": "x", "yField": "y", "color": "#ed0400"}}, {"title": "Data Drift", "field": "data_drift"}, {"title": "Stat Test", "field": "stattest_name"}, {"title": "Drift Score", "field": "drift_score"}], "data": [{"details": {"parts": [{"title": "DATA DISTRIBUTION", "id": "09d4e2f6-2df9-4ff4-a069-918941f8957e", "type": "widget"}]}, "column_name": "target", "column_type": "cat", "stattest_name": "chi-square p_value", "reference_distribution": {"x": [0, 1, 2], "y": [0, 40, 50]}, "current_distribution": {"x": [0, 1, 2], "y": [50, 10, 0]}, "data_drift": "Detected", "drift_score": 0.0}, {"details": {"parts": [{"title": "DATA DRIFT", "id": "438fce0b-cad4-4cf8-927b-62d8d5a3c72b", "type": "widget"}, {"title": "DATA DISTRIBUTION", "id": "229cd21e-516d-4ec4-a324-ba3d5f1a41ac", "type": "widget"}]}, "column_name": "sepal width (cm)", "column_type": "num", "stattest_name": "K-S p_value", "reference_distribution": {"x": [2.0, 2.18, 2.36, 2.54, 2.7199999999999998, 2.9, 3.08, 3.26, 3.44, 3.62, 3.8], "y": [0.06172839506172834, 0.30864197530864246, 0.6172839506172834, 0.8024691358024705, 0.7407407407407401, 1.7283950617283936, 0.7407407407407419, 0.3703703703703701, 0.06172839506172834, 0.12345679012345698]}, "current_distribution": {"x": [2.3, 2.51, 2.7199999999999998, 2.9299999999999997, 3.14, 3.35, 3.56, 3.7700000000000005, 3.9800000000000004, 4.19, 4.4], "y": [0.23809523809523814, 0.07936507936507937, 0.3174603174603175, 0.8730158730158714, 0.7936507936507938, 1.1904761904761907, 0.4761904761904753, 0.4761904761904763, 0.15873015873015875, 0.15873015873015875]}, "data_drift": "Detected", "drift_score": 0.0}, {"details": {"parts": [{"title": "DATA DRIFT", "id": "edc46d2c-327d-4069-848b-fcab7a01515f", "type": "widget"}, {"title": "DATA DISTRIBUTION", "id": "2bc63411-0e4b-4b96-91c2-48cdc905afe2", "type": "widget"}]}, "column_name": "sepal length (cm)", "column_type": "num", "stattest_name": "K-S p_value", "reference_distribution": {"x": [4.9, 5.2, 5.5, 5.800000000000001, 6.1000000000000005, 6.4, 6.7, 7.0, 7.300000000000001, 7.6, 7.9], "y": [0.14814814814814822, 0.037037037037037056, 0.7777777777777759, 0.5555555555555559, 0.4444444444444447, 0.4074074074074076, 0.5185185185185188, 0.18518518518518476, 0.03703703703703717, 0.2222222222222217]}, "current_distributi ...
#     var additional_graphs_evidently_dashboard_e5353efe5e41408db532e6694669ab9e = {"09d4e2f6-2df9-4ff4-a069-918941f8957e": {"type": "big_graph", "title": "", "size": 2, "id": "09d4e2f6-2df9-4ff4-a069-918941f8957e", "details": "", "alertsPosition": null, "alertStats": null, "params": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "visible": true, "x": [0, 1], "y": [50, 10], "type": "bar", "xaxis": "x", "yaxis": "y"}, {"marker": {"color": "#ed0400"}, "name": "current", "visible": false, "x": [0, 1], "y": [83.33333333333334, 16.666666666666664], "type": "bar", "xaxis": "x", "yaxis": "y"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "visible": true, "x": [2, 1], "y": [50, 40], "type": "bar", "xaxis": "x", "yaxis": "y"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "visible": false, "x": [2, 1], "y": [55.55555555555556, 44.44444444444444], "type": "bar", "xaxis": "x", "yaxis": "y"}], "layout": {"template": {"data": {"histogram2dcontour": [{"type": "histogram2dcontour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "choropleth":
